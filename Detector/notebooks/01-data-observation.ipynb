# %% [markdown]
# # Raw Data Observation

# %% [markdown]
# ### 1. Import the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 2. Load the dataset and display head

# %%
df = pd.read_csv(r'C:\Users\HP\Documents\PycharmProjects\network-anomaly-detector\Detector\data\UNSW-NB15.csv',
                 low_memory=False)
pd.set_option('display.max_columns', None)
print(df.sample(10))
# Out:
#                 srcip  sport           dstip dsport proto state       dur  \
# 754888     59.166.0.3  12433   149.171.126.5     21   tcp   FIN  2.280557
# 1460209  175.45.176.3  47439  149.171.126.18     53   udp   INT  0.000008
# 581543     59.166.0.2  16013   149.171.126.1     53   udp   CON  0.001098
# 2505163    59.166.0.3  46144   149.171.126.7  57988   tcp   FIN  0.021889
# 1554286    59.166.0.0  25301   149.171.126.1  23369   tcp   FIN  0.052056
# 1185352    59.166.0.8  58018   149.171.126.2  26949   tcp   FIN  0.004687
# 996223     59.166.0.2  25329   149.171.126.3     53   udp   CON  0.001039
# 636719     59.166.0.3  24204   149.171.126.5   5190   tcp   FIN  0.005950
# 2473279    59.166.0.9  36299   149.171.126.1   5190   tcp   FIN  3.336158
# 1863128    59.166.0.9  31136   149.171.126.5     53   udp   CON  0.001021
#
#          sbytes  dbytes  sttl  dttl  sloss  dloss service         Sload  \
# 754888     2934    3742    31    29     11     15     ftp  1.009578e+04
# 1460209     114       0   254     0      0      0     dns  5.700000e+07
# 581543      146     178    31    29      0      0     dns  5.318761e+05
# 2505163    2854   29122    31    29      7     17       -  1.020421e+06
# 1554286    2958   32408    31    29      7     18       -  4.452128e+05
# 1185352    4056    2456    31    29      7      7       -  6.538938e+06
# 996223      146     178    31    29      0      0     dns  5.620789e+05
# 636719     1920    4312    31    29      6      6       -  2.464538e+06
# 2473279   14088   45624    31    29     39     59       -  3.359553e+04
# 1863128     146     178    31    29      0      0     dns  5.719882e+05
#
#                 Dload  Spkts  Dpkts  swin  dwin       stcpb       dtcpb  \
# 754888   1.288457e+04     52     54   255   255  3626969762  3644214113
# 1460209  0.000000e+00      2      0     0     0           0           0
# 581543   6.484518e+05      2      2     0     0           0           0
# 2505163  1.042204e+07     46     48   255   255  4275958551  4280449863
# 1554286  4.880898e+06     48     50   255   255  3933986022  3942030658
# 1185352  3.959889e+06     18     18   255   255  1806854385  1809958784
# 996223   6.852743e+05      2      2     0     0           0           0
# 636719   5.556974e+06     22     24   255   255  1077006580  3222698690
# 2473279  1.088366e+05    180    192   255   255  3612816662  3613120548
# 1863128  6.973556e+05      2      2     0     0           0           0
#
#          smeansz  dmeansz  trans_depth  res_bdy_len         Sjit         Djit  \
# 754888        56       69            0            0  2940.350572    86.324234
# 1460209       57        0            0            0     0.000000     0.000000
# 581543        73       89            0            0     0.000000     0.000000
# 2505163       62      607            0            0    31.233305    31.730162
# 1554286       62      648            0            0     0.000000    70.434634
# 1185352      225      136            0            0    12.710605     0.322477
# 996223        73       89            0            0     0.000000     0.000000
# 636719        87      180            0            0    16.497309    13.732207
# 2473279       78      238            0            0  1223.701819  1187.495046
# 1863128       73       89            0            0     0.000000     0.000000
#
#               Stime       Ltime    Sintpkt    Dintpkt    tcprtt    synack  \
# 754888   1421958380  1421958383  44.710568  43.019906  0.000633  0.000497
# 1460209  1424232211  1424232211   0.008000   0.000000  0.000000  0.000000
# 581543   1421949786  1421949786   0.010000   0.009000  0.000000  0.000000
# 2505163  1424261159  1424261159   0.479578   0.473533  0.000707  0.000571
# 1554286  1424234637  1424234637   1.125000   1.051571  0.000672  0.000525
# 1185352  1424224228  1424224228   0.256765   0.245647  0.000634  0.000507
# 996223   1421968925  1421968925   0.011000   0.008000  0.000000  0.000000
# 636719   1421952277  1421952277   0.266381   0.231652  0.000756  0.000611
# 2473279  1424260471  1424260474  18.635754  17.463764  0.000692  0.000570
# 1863128  1424244137  1424244137   0.007000   0.007000  0.000000  0.000000
#
#            ackdat  is_sm_ips_ports  ct_state_ttl  ct_flw_http_mthd  \
# 754888   0.000136                0             0               0.0
# 1460209  0.000000                0             2               NaN
# 581543   0.000000                0             0               0.0
# 2505163  0.000136                0             0               NaN
# 1554286  0.000147                0             0               NaN
# 1185352  0.000127                0             0               NaN
# 996223   0.000000                0             0               0.0
# 636719   0.000145                0             0               0.0
# 2473279  0.000122                0             0               NaN
# 1863128  0.000000                0             0               NaN
#
#          is_ftp_login ct_ftp_cmd  ct_srv_src  ct_srv_dst  ct_dst_ltm  \
# 754888            0.0          0           1           1           4
# 1460209           NaN                     36          36          19
# 581543            0.0          0           2           1           1
# 2505163           NaN                      8           6           3
# 1554286           NaN                      9           6           2
# 1185352           NaN                      4           6           5
# 996223            0.0          0           1           4           4
# 636719            0.0          0          11          11           2
# 2473279           NaN                      4           2           5
# 1863128           NaN                      2           1           1
#
#          ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 754888             2                 1                 1               2
# 1460209           18                18                18              36
# 581543             3                 1                 1               1
# 2505163            3                 1                 1               2
# 1554286            5                 1                 1               2
# 1185352            5                 1                 1               4
# 996223             1                 1                 1               1
# 636719             1                 1                 1               1
# 2473279            3                 1                 1               1
# 1863128            7                 2                 1               1
#
#         attack_cat  Label
# 754888         NaN      0
# 1460209    Generic      1
# 581543         NaN      0
# 2505163        NaN      0
# 1554286        NaN      0
# 1185352        NaN      0
# 996223         NaN      0
# 636719         NaN      0
# 2473279        NaN      0
# 1863128        NaN      0

# %% [markdown]
# ### 3. Shape & missing values

# %%
print(df.isnull().sum())
print(df.shape)
# Out:
# srcip                     0
# sport                     0
# dstip                     0
# dsport                    0
# proto                     0
# state                     0
# dur                       0
# sbytes                    0
# dbytes                    0
# sttl                      0
# dttl                      0
# sloss                     0
# dloss                     0
# service                   0
# Sload                     0
# Dload                     0
# Spkts                     0
# Dpkts                     0
# swin                      0
# dwin                      0
# stcpb                     0
# dtcpb                     0
# smeansz                   0
# dmeansz                   0
# trans_depth               0
# res_bdy_len               0
# Sjit                      0
# Djit                      0
# Stime                     0
# Ltime                     0
# Sintpkt                   0
# Dintpkt                   0
# tcprtt                    0
# synack                    0
# ackdat                    0
# is_sm_ips_ports           0
# ct_state_ttl              0
# ct_flw_http_mthd    1348145
# is_ftp_login        1429879
# ct_ftp_cmd                0
# ct_srv_src                0
# ct_srv_dst                0
# ct_dst_ltm                0
# ct_src_ ltm               0
# ct_src_dport_ltm          0
# ct_dst_sport_ltm          0
# ct_dst_src_ltm            0
# attack_cat          2218764
# Label                     0
# dtype: int64
# (2540047, 49)

# %% [markdown]
# ### 4. Datatypes

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2540047 entries, 0 to 2540046
# Data columns (total 49 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   srcip             str
#  1   sport             str
#  2   dstip             str
#  3   dsport            str
#  4   proto             str
#  5   state             str
#  6   dur               float64
#  7   sbytes            int64
#  8   dbytes            int64
#  9   sttl              int64
#  10  dttl              int64
#  11  sloss             int64
#  12  dloss             int64
#  13  service           str
#  14  Sload             float64
#  15  Dload             float64
#  16  Spkts             int64
#  17  Dpkts             int64
#  18  swin              int64
#  19  dwin              int64
#  20  stcpb             int64
#  21  dtcpb             int64
#  22  smeansz           int64
#  23  dmeansz           int64
#  24  trans_depth       int64
#  25  res_bdy_len       int64
#  26  Sjit              float64
#  27  Djit              float64
#  28  Stime             int64
#  29  Ltime             int64
#  30  Sintpkt           float64
#  31  Dintpkt           float64
#  32  tcprtt            float64
#  33  synack            float64
#  34  ackdat            float64
#  35  is_sm_ips_ports   int64
#  36  ct_state_ttl      int64
#  37  ct_flw_http_mthd  float64
#  38  is_ftp_login      float64
#  39  ct_ftp_cmd        str
#  40  ct_srv_src        int64
#  41  ct_srv_dst        int64
#  42  ct_dst_ltm        int64
#  43  ct_src_ ltm       int64
#  44  ct_src_dport_ltm  int64
#  45  ct_dst_sport_ltm  int64
#  46  ct_dst_src_ltm    int64
#  47  attack_cat        str
#  48  Label             int64
# dtypes: float64(12), int64(28), str(9)
# memory usage: 949.6 MB

# %% [markdown]
# ### 5. Unique values

# %%
df.nunique()
# Out:
# srcip                    43
# sport                 64600
# dstip                    47
# dsport                64630
# proto                   135
# state                    16
# dur                  587303
# sbytes                14155
# dbytes                19166
# sttl                     13
# dttl                     11
# sloss                   544
# dloss                   707
# service                  13
# Sload               1100258
# Dload               1173739
# Spkts                   933
# Dpkts                  1255
# swin                     36
# dwin                     32
# stcpb               1429571
# dtcpb               1429031
# smeansz                1415
# dmeansz                1417
# trans_depth              14
# res_bdy_len            2907
# Sjit                1381001
# Djit                1424689
# Stime                 85348
# Ltime                 85361
# Sintpkt              975275
# Dintpkt              960353
# tcprtt                76931
# synack                66997
# ackdat                60844
# is_sm_ips_ports           2
# ct_state_ttl              7
# ct_flw_http_mthd         16
# is_ftp_login              4
# ct_ftp_cmd                9
# ct_srv_src               65
# ct_srv_dst               66
# ct_dst_ltm               62
# ct_src_ ltm              62
# ct_src_dport_ltm         62
# ct_dst_sport_ltm         55
# ct_dst_src_ltm           65
# attack_cat               13
# Label                     2
# dtype: int64

# %% [markdown]
# ### 6. Duplicates

# %%
print(df.duplicated().sum())
df[df.duplicated(keep=False)].head(20)
# Out:
# 480633
#             srcip  sport          dstip dsport proto state        dur  sbytes  \
# 7     10.40.182.3      0    10.40.182.3      0   arp   INT   0.000000      46
# 10    10.40.170.2      0    10.40.170.2      0   arp   INT   0.000000      46
# 11    10.40.170.2      0    10.40.170.2      0   arp   INT   0.000000      46
# 12    10.40.182.3      0    10.40.182.3      0   arp   INT   0.000000      46
# 70     59.166.0.6  15807  149.171.126.7     53   udp   CON   0.001118     132
# 72     59.166.0.6  15807  149.171.126.7     53   udp   CON   0.001118     132
# 119   10.40.182.1      0      224.0.0.5      0  ospf   INT  50.004337     384
# 120    10.40.85.1      0      224.0.0.5      0  ospf   INT  50.004341     384
# 121   10.40.182.1      0      224.0.0.5      0  ospf   INT  50.004337     384
# 122    10.40.85.1      0      224.0.0.5      0  ospf   INT  50.004341     384
# 186    59.166.0.3  59680  149.171.126.3     53   udp   CON   0.001083     130
# 187    59.166.0.3  59680  149.171.126.3     53   udp   CON   0.001083     130
# 525   10.40.85.30      0     10.40.85.1      0   arp   CON  30.788803     138
# 526   10.40.182.1      0    10.40.182.3      0   arp   CON  31.328632      56
# 527   10.40.182.1      0    10.40.182.3      0   arp   CON  31.328632      56
# 528   10.40.85.30      0     10.40.85.1      0   arp   CON  30.788803     138
# 791    59.166.0.6  24963  149.171.126.5   5190   tcp   FIN  18.769098    2024
# 798    59.166.0.6  24963  149.171.126.5   5190   tcp   FIN  18.769098    2024
# 1019   59.166.0.1  62932  149.171.126.7   6881   tcp   FIN   5.756042    1540
# 1033   59.166.0.1  62932  149.171.126.7   6881   tcp   FIN   5.756042    1540
#
#       dbytes  sttl  dttl  sloss  dloss service          Sload          Dload  \
# 7          0     0     0      0      0       -       0.000000       0.000000
# 10         0     0     0      0      0       -       0.000000       0.000000
# 11         0     0     0      0      0       -       0.000000       0.000000
# 12         0     0     0      0      0       -       0.000000       0.000000
# 70       164    31    29      0      0     dns  472271.906300  586762.062500
# 72       164    31    29      0      0     dns  472271.906300  586762.062500
# 119        0     1     0      0      0       -      51.195560       0.000000
# 120        0     1     0      0      0       -      51.195557       0.000000
# 121        0     1     0      0      0       -      51.195560       0.000000
# 122        0     1     0      0      0       -      51.195557       0.000000
# 186      162    31    29      0      0     dns  480147.750000  598337.937500
# 187      162    31    29      0      0     dns  480147.750000  598337.937500
# 525       84     0     0      0      0       -      23.904795      14.550744
# 526       92     0     0      0      0       -       7.150009      11.746443
ct_dst_ltm  ct_src_ ltm  ct_src_dport_ltm  \
# count 2,540,047.00 2,540,047.00 2,540,047.00 2,540,047.00      2,540,047.00
# mean          9.21         8.99         6.44         6.90              4.64
# std          10.84        10.82         8.16         8.21              8.48
# min           1.00         1.00         1.00         1.00              1.00
# 25%           2.00         2.00         2.00         2.00              1.00
# 50%           5.00         5.00         3.00         4.00              1.00
# 75%          10.00        10.00         6.00         7.00              2.00
# max          67.00        67.00        67.00        67.00             67.00
#
#        ct_dst_sport_ltm  ct_dst_src_ltm        Label
# count      2,540,047.00    2,540,047.00 2,540,047.00
# mean               3.59            6.85         0.13
# std                6.17           11.26         0.33
# min                1.00            1.00         0.00
# 25%                1.00            1.00         0.00
# 50%                1.00            2.00         0.00
# 75%                1.00            5.00         0.00
# max               60.00           67.00         1.00

# %% [markdown]
# Initial Observation
# 1. The dataset contains 2540047 Entries and 49 Features
# 2. Three features contains NULL values
# 3. Most of the columns are Heavily Right Skewed
# 4. Data ranges are very wide scalling is needed
# 5. Many columns may contain outliers
# 6. There are 480633 duplicate rows

# %% [markdown]
# ### 8. Correlation with target Feature

# %%
correlation = (df.corr(numeric_only=True)["Label"].sort_values(key = abs , ascending = False))
correlation
# Out:
# Label               1.000000
# sttl                0.904393
# ct_state_ttl        0.873694
# ct_dst_src_ltm      0.439916
# ct_dst_sport_ltm    0.419056
# ct_src_dport_ltm    0.396749
# ct_srv_dst          0.386509
# ct_srv_src          0.383007
# ct_src_ ltm         0.343246
# ct_dst_ltm          0.339464
# swin               -0.315108
# dwin               -0.313920
# Ltime               0.275660
# Stime               0.275660
# dmeansz            -0.272397
# dtcpb              -0.233513
# stcpb              -0.233422
# Dload              -0.219710
# Sload               0.192278
# ackdat              0.143443
# tcprtt              0.143109
# dttl                0.134947
# synack              0.122253
# Spkts              -0.120880
# Dpkts              -0.115947
# dloss              -0.095855
# ct_flw_http_mthd    0.083188
# dbytes             -0.075543
# smeansz            -0.065363
# Djit               -0.054420
# sloss              -0.043272
# is_ftp_login        0.031956
# trans_depth        -0.029041
# res_bdy_len        -0.027339
# Sjit                0.020959
# Sintpkt            -0.019034
# is_sm_ips_ports    -0.015477
# Dintpkt            -0.010632
# sbytes              0.010180
# dur                 0.001959
# Name: Label, dtype: float64

# %% [markdown]
# ### 9. Histograms

# %%
columns = ["dur", "sbytes", "dbytes", "Sload", "Dload", "Spkts","Dpkts","res_bdy_len",'Sjit','Djit','Sintpkt','Dintpkt']

plt.figure(figsize=(15, 8))

for i, column in enumerate(columns):
    plt.subplot(4, 3, i + 1)
    plt.hist(np.log1p(df[column]), bins=50)
    plt.title(f"{column} - Log Transformed")

plt.tight_layout()
plt.show()

# %% [markdown]
# The features are is extremely right skewed, most of the values are near to 0 while some very large values extends the x axis suspected as outliers, log transformation has made the underlying distributions visible

# %% [markdown]
# ### 10. Distributions of categorical and output column

# %%
for col in df.columns:
    if df[col].nunique() < 15:
        print(df[col].value_counts())
# Out:
# sttl
# 31     1940700
# 254     331288
# 60      214255
# 62       29963
# 0        10448
# 1         4520
# 64        3625
# 29        2736
# 32        1602
# 63         526
# 30         225
# 252         84
# 255         75
# Name: count, dtype: int64
# dttl
# 29     1939967
# 0       506076
# 252      85234
# 60        4304
# 31        2405
# 30        1789
# 32         194
# 254         60
# 253         11
# 62           6
# 64           1
# Name: count, dtype: int64
# service
# -           1246397
# dns          781668
# http         206273
# ftp-data     125783
# smtp          81645
# ftp           49090
# ssh           47160
# pop3           1533
# dhcp            172
# ssl             142
# snmp            113
# radius           40
# irc              31
# Name: count, dtype: int64
# trans_depth
# 0      2334925
# 1       199573
# 2         5530
# 3            4
# 4            4
# 5            2
# 39           2
# 8            1
# 131          1
# 9            1
# 80           1
# 155          1
# 163          1
# 172          1
# Name: count, dtype: int64
# is_sm_ips_ports
# 0    2535852
# 1       4195
# Name: count, dtype: int64
# ct_state_ttl
# 0    2178185
# 2     272003
# 1      81396
# 3       4251
# 6       4170
# 4         40
# 5          2
# Name: count, dtype: int64
# is_ftp_login
# 0.0    1066593
# 1.0      43389
# 4.0        156
# 2.0         30
# Name: count, dtype: int64
# ct_ftp_cmd
#      1429879
# 0    1066498
# 1      40077
# 2       1264
# 4        960
# 3        729
# 6        332
# 5        290
# 8         18
# Name: count, dtype: int64
# attack_cat
# Generic             215481
# Exploits             44525
#  Fuzzers             19195
# DoS                  16353
#  Reconnaissance      12228
#  Fuzzers              5051
# Analysis              2677
# Backdoor              1795
# Reconnaissance        1759
#  Shellcode            1288
# Backdoors              534
# Shellcode              223
# Worms                  174
# Name: count, dtype: int64
# Label
# 0    2218764
# 1     321283
# Name: count, dtype: int64

# %% [markdown]
# ### 11. Heatmap of most correlated columns

# %%
top_features = (
    df.corr(numeric_only=True)["Label"].sort_values(key = abs , ascending = False).head(15).index
)

corr = df[top_features].corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr, cmap='coolwarm', center =0, annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 12. Heatmap with least correlated features

# %%
top_features = (
    df.corr(numeric_only=True)["Label"].sort_values(key = abs , ascending = False).tail(15).index
)

corr = df[top_features].corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr, cmap='coolwarm', center =0, annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 13.All features heatmap

# %%
plt.figure(figsize=(40,20))
sns.heatmap(df.corr(numeric_only = True), cmap='coolwarm', center =0, annot = True)
plt.show()

# %% [markdown]
# ### 14. Scatter-Plots

# %%
pairs = [
    ('sttl','ct_state_ttl'),
    ('ct_srv_src','ct_dst_ltm'),
    ('ct_src_dport_ltm','ct_dst_ltm'),
    ('dloss','dbytes')
]

sample = df.sample(25000)
fig, axes = plt.subplots(2, 2, figsize = (15,10))

for ax,(x,y) in zip(axes.flat , pairs):
    sns.scatterplot(
        data=sample,
        x=x,
        y=y,
        hue='Label',
        ax=ax
    )
    ax.set_title(f"{x} - {y}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 15. Box - PLot

# %%
cols = ['dur','sbytes','dbytes','sloss','dloss','Sload','Dload','Spkts','Dpkts','trans_depth','res_bdy_len','Sjit','Djit','Sintpkt','Dintpkt']

df_log = np.log1p(df[cols])
df_log = pd.DataFrame(df_log, columns = cols)
df_log.plot(kind='box',subplots=True,layout=(3,5),figsize=(15,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# Final Observations:
# 1. Various features has extreme outliers, and they tend to be attack signals
# 2. There are about 9 columns that have good correlation with Label ( target ) column
# 3. Scatterplot Shows dloss and dbyte values are overlapping that mean they are highly redundat and greater the value shows better possibility of attack
